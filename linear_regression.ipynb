# %%
#Import the experimental dataset (the file contains all experiments performed up to 4GPa)
exp_cpx<- read.delim("CPX_experiments.txt")

# %%
#Al2O3 in cpx seems to show a good relationships with pressure
plot(exp_cpx$Al2O3.cpx, exp_cpx$P_GPa, pch=19, col="red", ylab="Experimental Pressure [GPa]", xlab="Al2O3 in cpx")

# %% [markdown]
# Let's try to fit a linear regression through the data using only Al2O3 as independent variable

# %%
Y <- exp_cpx$P_GPa
X <- exp_cpx$Al2O3.cpx
xlab<- "Al2O3 [wt.%]"
ylab<- "Experimental Pressure [GPa]"

model.data <- data.frame(Y,X)
linearMod <- lm(Y ~ X, data=model.data)
summary(linearMod)


plot(X,Y,pch=21,col="grey",bg="black",xlab=xlab,ylab=ylab)
lines(sort(X), fitted(linearMod)[order(X)], col='red', type='l',lwd=2)
# Out:
# Call:
# lm(formula = Y ~ X, data = model.data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.3373 -0.3312 -0.0734  0.3104  3.3292
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.125077   0.032392  -3.861 0.000118 ***
# X            0.162757   0.004809  33.842  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6149 on 1349 degrees of freedom
# Multiple R-squared:  0.4592,	Adjusted R-squared:  0.4588
# F-statistic:  1145 on 1 and 1349 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# What about a non linear model?

# %%
nonlinearMod <- lm(Y ~ I(X^0.5), data=model.data)
print(nonlinearMod)
summary(nonlinearMod)

plot(X,Y,pch=21,col="grey",bg="black",xlab=xlab,ylab=ylab)
lines(sort(X), fitted(nonlinearMod)[order(X)], col='red', type='l',lwd=2)
# Out:
# Call:
# lm(formula = Y ~ I(X^0.5), data = model.data)
#
# Coefficients:
# (Intercept)     I(X^0.5)
#     -0.9669       0.7763
# Call:
# lm(formula = Y ~ I(X^0.5), data = model.data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.0525 -0.3503 -0.0636  0.3310  3.2503
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.96688    0.05757  -16.79   <2e-16 ***
# I(X^0.5)     0.77627    0.02397   32.38   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6272 on 1349 degrees of freedom
# Multiple R-squared:  0.4373,	Adjusted R-squared:  0.4369
# F-statistic:  1049 on 1 and 1349 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# Try to check for the relationship between temperature and pressure

# %%
Y <- exp_cpx$P_GPa
X <- exp_cpx$T_K
xlab<- "Temperature [K]"
ylab<- "Experimental Pressure [GPa]"

model.data <- data.frame(Y,X)
linearMod <- lm(Y ~ X, data=model.data)
summary(linearMod)


plot(X,Y,pch=21,col="grey",bg="black",xlab=xlab,ylab=ylab)
lines(sort(X), fitted(linearMod)[order(X)], col='red', type='l',lwd=2)
# Out:
# Call:
# lm(formula = Y ~ X, data = model.data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.53761 -0.52292 -0.08155  0.31037  2.88410
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -3.7993123  0.1620311  -23.45   <2e-16 ***
# X            0.0032323  0.0001128   28.64   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6593 on 1349 degrees of freedom
# Multiple R-squared:  0.3782,	Adjusted R-squared:  0.3778
# F-statistic: 820.6 on 1 and 1349 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# You can check what the regression summary values mean here: https://feliperego.github.io/blog/2015/10/23/Interpreting-Model-Output-In-R

# %% [markdown]
# What about a non linear model?

# %%
nonlinearMod <- lm(Y ~ I(X^6), data=model.data)
print(nonlinearMod)
summary(nonlinearMod)

plot(X,Y,pch=21,col="grey",bg="black",xlab=xlab,ylab=ylab)
lines(sort(X), fitted(nonlinearMod)[order(X)], col='red', type='l',lwd=2)
# Out:
# Call:
# lm(formula = Y ~ I(X^6), data = model.data)
#
# Coefficients:
# (Intercept)       I(X^6)
#  -9.275e-02    9.023e-20
# Call:
# lm(formula = Y ~ I(X^6), data = model.data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.73561 -0.44577 -0.05738  0.22506  2.90847
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -9.275e-02  2.964e-02  -3.129  0.00179 **
# I(X^6)       9.023e-20  2.475e-21  36.461  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.5934 on 1349 degrees of freedom
# Multiple R-squared:  0.4963,	Adjusted R-squared:  0.496
# F-statistic:  1329 on 1 and 1349 DF,  p-value: < 2.2e-16
# plot without title
